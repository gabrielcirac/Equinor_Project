# %%
# %%capture capturado
# %matplotlib widget
# %matplotlib inline
# %%capture --no-stderr
import os
import warnings
import logging

"""Suppress TensorFlow and addon warnings for a cleaner console."""
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['ABSL_LOG_LEVEL'] = '3'
warnings.filterwarnings(
    'ignore',
    category=UserWarning,
    module='tensorflow_addons'
)
import tensorflow as tf
tf.get_logger().setLevel('ERROR')

from colorlog import ColoredFormatter

from forecast_pipeline.config import LOG_LEVEL, DEFAULT_EXP_PARAMS
from forecast_pipeline.jobs import (
    generate_jobs,
    select_data_sources,
    create_filter_configurations,
)
from forecast_pipeline.metrics import (
    collate_metrics,
    clean_and_structure_results,
)
from forecast_pipeline.io_utils import (
    generate_experiment_name,
    save_experiment_to_excel,
)
from forecast_pipeline.runner import execute_jobs, run_experiments_for_config
from common.config_wells import DATA_SOURCES
from forecast_pipeline.config import DEFAULT_DATASET
# Out:
# INFO: Carregadas 6 arquiteturas e 5 perfis de hiperparâmetros.

# %%
# %%capture capturado
def configure_logging():
    """Set up a colored logger respecting the global LOG_LEVEL."""
    handler = logging.StreamHandler()
    handler.setFormatter(
        ColoredFormatter(
            "%(log_color)s%(asctime)s [%(levelname)-7s] %(message)s",
            datefmt="%Y-%m-%d %H:%M:%S",
            log_colors={
                'DEBUG':    'cyan',
                'INFO':     'blue',
                'WARNING':  'yellow',
                'ERROR':    'red',
                'CRITICAL': 'bold_red',
            }
        )
    )
    root = logging.getLogger()
    root.handlers = [handler]
    # Map 0→WARNING, 1→INFO, 2→DEBUG
    level = {0: logging.WARNING, 1: logging.INFO, 2: logging.DEBUG}
    root.setLevel(level.get(LOG_LEVEL, logging.INFO))



# ─── executa tudo ───────────────────────────────────────────────
def main(
    ensemble_models: int = 1,
    filter_methods: list = None,
    selected_sources: list = None
) -> dict:
    """End-to-end pipeline: select sources, iterate configs, run and collect all results."""
    logging.info("Starting main pipeline…")
    sources = select_data_sources(DATA_SOURCES, selected_sources)
    if not sources:
        logging.warning("No data sources selected; exiting.")
        return {}

    results = {}
    for cfg in create_filter_configurations(filter_methods):
        results.update(run_experiments_for_config(cfg, sources, ensemble_models))

    logging.info("Pipeline finished.")
    return results


if __name__ == "__main__":
    configure_logging()

    # User parameters
    ensemble_size = 5

    # Run experiments
    results = main(
        ensemble_models=ensemble_size,
        filter_methods=None,
        selected_sources=DEFAULT_DATASET
    )


    # Save to Excel
    exp_name = generate_experiment_name(
        DEFAULT_DATASET,
        DEFAULT_EXP_PARAMS["architecture_name"],
        ensemble_size
    )
    
    output_path = save_experiment_to_excel(
        DEFAULT_EXP_PARAMS,
        results,
        exp_name,
        DEFAULT_DATASET,
        ensemble_size,
    )
    logging.info(f"Results saved to: {output_path}")
# Out:
# 2025-07-02 17:02:41 [INFO   ] Starting main pipeline…
# 2025-07-02 17:02:41 [INFO   ] No filter methods provided; running with no adaptive filtering.
# 2025-07-02 17:02:41 [INFO   ] Dispatching 10 jobs
# Jobs:   0%|          | 0/10 [00:00<?, ?job/s]
# 2025-07-02 17:02:42 [INFO   ] → Beginning process_chunks: total=5, chunk=5
# 2025-07-02 17:02:42 [INFO   ]   → Batch 1/1 (size=5)
# 2025-07-02 17:02:42 [INFO   ] → Launching chunk of 5 models
# 2025-07-02 17:02:42 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:02:42 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:02:42 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:02:42 [INFO   ] Extractor: {'type': 'rnn'}
# 2025-07-02 17:02:42 [INFO   ] Fuser: {'type': 'bias_scale'}
# 2025-07-02 17:02:42 [INFO   ] → Beginning process_chunks: total=5, chunk=5
# 2025-07-02 17:02:42 [INFO   ]   → Batch 1/1 (size=5)
# 2025-07-02 17:02:42 [INFO   ] → Launching chunk of 5 models
# 2025-07-02 17:02:42 [INFO   ] → Beginning process_chunks: total=5, chunk=5
# 2025-07-02 17:02:42 [INFO   ]   → Batch 1/1 (size=5)
# 2025-07-02 17:02:42 [INFO   ] → Launching chunk of 5 models
# 2025-07-02 17:02:42 [INFO   ] → Beginning process_chunks: total=5, chunk=5
# 2025-07-02 17:02:42 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:02:42 [INFO   ]   → Batch 1/1 (size=5)
# 2025-07-02 17:02:42 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:02:42 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:02:42 [INFO   ] → Launching chunk of 5 models
# 2025-07-02 17:02:42 [INFO   ] Extractor: {'type': 'tcn'}
# 2025-07-02 17:02:42 [INFO   ] Fuser: {'type': 'film'}
# 2025-07-02 17:02:42 [INFO   ] → Beginning process_chunks: total=5, chunk=5
# 2025-07-02 17:02:42 [INFO   ] → Beginning process_chunks: total=5, chunk=5
# 2025-07-02 17:02:42 [INFO   ]   → Batch 1/1 (size=5)
# 2025-07-02 17:02:42 [INFO   ]   → Batch 1/1 (size=5)
# 2025-07-02 17:02:42 [INFO   ] → Launching chunk of 5 models
# 2025-07-02 17:02:42 [INFO   ] → Launching chunk of 5 models
# 2025-07-02 17:02:42 [INFO   ] → Beginning process_chunks: total=5, chunk=5
# 2025-07-02 17:02:42 [INFO   ] → Beginning process_chunks: total=5, chunk=5
# 2025-07-02 17:02:42 [INFO   ]   → Batch 1/1 (size=5)
# 2025-07-02 17:02:42 [INFO   ]   → Batch 1/1 (size=5)
# 2025-07-02 17:02:42 [INFO   ] → Launching chunk of 5 models
# 2025-07-02 17:02:42 [INFO   ] → Launching chunk of 5 models
# 2025-07-02 17:02:42 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:02:42 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:02:42 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:02:42 [INFO   ] Extractor: {'type': 'cnn'}
# 2025-07-02 17:02:42 [INFO   ] Fuser: {'type': 'film'}
# 2025-07-02 17:02:42 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:02:42 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:02:42 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:02:42 [INFO   ] Extractor: {'type': 'aggregate'}
# 2025-07-02 17:02:42 [INFO   ] Fuser: {'type': 'film'}
# 2025-07-02 17:02:42 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:02:42 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:02:42 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:02:42 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:02:42 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:02:42 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:02:42 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:02:42 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:02:42 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:02:42 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:02:42 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:02:42 [INFO   ] Extractor: {'type': 'rnn'}
# 2025-07-02 17:02:42 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:02:42 [INFO   ] Extractor: {'type': 'cnn'}
# 2025-07-02 17:02:42 [INFO   ] Extractor: {'type': 'aggregate'}
# 2025-07-02 17:02:42 [INFO   ] Fuser: {'type': 'film'}
# 2025-07-02 17:02:42 [INFO   ] Extractor: {'type': 'tcn'}
# 2025-07-02 17:02:42 [INFO   ] Fuser: {'type': 'bias_scale'}
# 2025-07-02 17:02:42 [INFO   ] Fuser: {'type': 'bias_scale'}
# 2025-07-02 17:02:42 [INFO   ] Fuser: {'type': 'bias_scale'}
# 2025-07-02 17:02:43 [INFO   ] training_mode: traditional
# 2025-07-02 17:02:43 [INFO   ] training_mode: traditional
# 2025-07-02 17:02:43 [INFO   ] training_mode: traditional
# 2025-07-02 17:02:43 [INFO   ] training_mode: traditional
# 2025-07-02 17:02:43 [INFO   ] training_mode: traditional
# 2025-07-02 17:02:43 [INFO   ] training_mode: traditional
# 2025-07-02 17:02:43 [INFO   ] training_mode: traditional
# 2025-07-02 17:02:43 [INFO   ] training_mode: traditional
# 2025-07-02 17:04:01 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:04:01 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:04:01 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:04:01 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:04:01 [INFO   ] Extractor: {'type': 'aggregate'}
# 2025-07-02 17:04:01 [INFO   ] Fuser: {'type': 'bias_scale'}
# 2025-07-02 17:04:01 [INFO   ] training_mode: traditional
# 2025-07-02 17:04:03 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:04:03 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:04:03 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:04:03 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:04:03 [INFO   ] Extractor: {'type': 'aggregate'}
# 2025-07-02 17:04:03 [INFO   ] Fuser: {'type': 'film'}
# 2025-07-02 17:04:03 [INFO   ] training_mode: traditional
# 2025-07-02 17:04:46 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:04:46 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:04:46 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:04:46 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:04:46 [INFO   ] Extractor: {'type': 'cnn'}
# 2025-07-02 17:04:46 [INFO   ] Fuser: {'type': 'bias_scale'}
# 2025-07-02 17:04:47 [INFO   ] training_mode: traditional
# 2025-07-02 17:05:18 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:05:18 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:05:18 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:05:18 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:05:18 [INFO   ] Extractor: {'type': 'cnn'}
# 2025-07-02 17:05:18 [INFO   ] Fuser: {'type': 'film'}
# 2025-07-02 17:05:19 [INFO   ] training_mode: traditional
# 2025-07-02 17:05:19 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:05:19 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:05:19 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:05:19 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:05:19 [INFO   ] Extractor: {'type': 'aggregate'}
# 2025-07-02 17:05:19 [INFO   ] Fuser: {'type': 'bias_scale'}
# 2025-07-02 17:05:19 [INFO   ] training_mode: traditional
# 2025-07-02 17:05:21 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:05:21 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:05:21 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:05:21 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:05:21 [INFO   ] Extractor: {'type': 'aggregate'}
# 2025-07-02 17:05:21 [INFO   ] Fuser: {'type': 'film'}
# 2025-07-02 17:05:21 [INFO   ] training_mode: traditional
# 2025-07-02 17:06:40 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:06:41 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:06:41 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:06:41 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:06:41 [INFO   ] Extractor: {'type': 'aggregate'}
# 2025-07-02 17:06:41 [INFO   ] Fuser: {'type': 'bias_scale'}
# 2025-07-02 17:06:41 [INFO   ] training_mode: traditional
# 2025-07-02 17:06:46 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:06:47 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:06:47 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:06:47 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:06:47 [INFO   ] Extractor: {'type': 'aggregate'}
# 2025-07-02 17:06:47 [INFO   ] Fuser: {'type': 'film'}
# 2025-07-02 17:06:47 [INFO   ] training_mode: traditional
# 2025-07-02 17:06:48 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:06:48 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:06:48 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:06:48 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:06:48 [INFO   ] Extractor: {'type': 'cnn'}
# 2025-07-02 17:06:48 [INFO   ] Fuser: {'type': 'bias_scale'}
# 2025-07-02 17:06:49 [INFO   ] training_mode: traditional
# 2025-07-02 17:07:59 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:07:59 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:07:59 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:07:59 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:07:59 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:07:59 [INFO   ] Extractor: {'type': 'cnn'}
# 2025-07-02 17:07:59 [INFO   ] Fuser: {'type': 'film'}
# 2025-07-02 17:07:59 [INFO   ] training_mode: traditional
# 2025-07-02 17:08:00 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:08:00 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:08:00 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:08:00 [INFO   ] Extractor: {'type': 'aggregate'}
# 2025-07-02 17:08:00 [INFO   ] Fuser: {'type': 'bias_scale'}
# 2025-07-02 17:08:00 [INFO   ] training_mode: traditional
# 2025-07-02 17:08:08 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:08:09 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:08:09 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:08:09 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:08:09 [INFO   ] Extractor: {'type': 'aggregate'}
# 2025-07-02 17:08:09 [INFO   ] Fuser: {'type': 'film'}
# 2025-07-02 17:08:09 [INFO   ] training_mode: traditional
# 2025-07-02 17:08:51 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:08:52 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:08:52 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:08:52 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:08:52 [INFO   ] Extractor: {'type': 'cnn'}
# 2025-07-02 17:08:52 [INFO   ] Fuser: {'type': 'bias_scale'}
# 2025-07-02 17:08:52 [INFO   ] training_mode: traditional
# 2025-07-02 17:09:16 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:09:17 [INFO   ] Trend Contribution: 1.00% | Physics Contribution: 1.00%
# 2025-07-02 17:09:18 [INFO   ] ← Chunk complete, 5 models aggregated
# 2025-07-02 17:09:18 [INFO   ]   → dict_keys(['successful_models', 'alpha', 'pred_test', 'res_test', 'alpha_test', 'pred_val', 'q_phys', 'res_val', 'alpha_val'])
# 2025-07-02 17:09:18 [INFO   ]   ← Batch 1 done, total models so far: 5/5
# 2025-07-02 17:09:18 [INFO   ] ← Running contribution analysis on aggregated test results
# 2025-07-02 17:09:18 [INFO   ] [Original-units] Mean point-wise physics contribution: 43.11%
# 2025-07-02 17:09:18 [INFO   ] [Original-units] Global physics contribution: 43.17% (alpha média: 30.18%)
# 2025-07-02 17:09:18 [INFO   ] === Contribution Analysis Summary (unidades originais) ===
#
# • Point-wise mean:       43.11%
# • Global aggregate:      43.17% (alpha média: 30.18%)
# 2025-07-02 17:09:18 [INFO   ] ← process_chunks complete, returning test and validation predictions
# 2025-07-02 17:09:19 [INFO   ] → Beginning process_chunks: total=5, chunk=5
# 2025-07-02 17:09:19 [INFO   ]   → Batch 1/1 (size=5)
# 2025-07-02 17:09:19 [INFO   ] → Launching chunk of 5 models
# 2025-07-02 17:09:19 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:09:19 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:09:19 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:09:19 [INFO   ] Extractor: {'type': 'identity'}
# 2025-07-02 17:09:19 [INFO   ] Fuser: {'type': 'film'}
# 2025-07-02 17:09:20 [INFO   ] training_mode: traditional
# 2025-07-02 17:09:28 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:09:29 [INFO   ] Trend Contribution: 1.00% | Physics Contribution: 1.00%
# 2025-07-02 17:09:30 [INFO   ] ← Chunk complete, 5 models aggregated
# 2025-07-02 17:09:30 [INFO   ]   → dict_keys(['successful_models', 'alpha', 'pred_test', 'res_test', 'alpha_test', 'pred_val', 'q_phys', 'res_val', 'alpha_val'])
# 2025-07-02 17:09:30 [INFO   ]   ← Batch 1 done, total models so far: 5/5
# 2025-07-02 17:09:30 [INFO   ] ← Running contribution analysis on aggregated test results
# 2025-07-02 17:09:30 [INFO   ] [Original-units] Mean point-wise physics contribution: 46.37%
# 2025-07-02 17:09:30 [INFO   ] [Original-units] Global physics contribution: 46.53% (alpha média: 30.35%)
# 2025-07-02 17:09:30 [INFO   ] === Contribution Analysis Summary (unidades originais) ===
#
# • Point-wise mean:       46.37%
# • Global aggregate:      46.53% (alpha média: 30.35%)
# 2025-07-02 17:09:30 [INFO   ] ← process_chunks complete, returning test and validation predictions
# 2025-07-02 17:09:31 [INFO   ] → Beginning process_chunks: total=5, chunk=5
# 2025-07-02 17:09:31 [INFO   ]   → Batch 1/1 (size=5)
# 2025-07-02 17:09:31 [INFO   ] → Launching chunk of 5 models
# 2025-07-02 17:09:31 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:09:31 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:09:31 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:09:31 [INFO   ] Extractor: {'type': 'identity'}
# 2025-07-02 17:09:31 [INFO   ] Fuser: {'type': 'bias_scale'}
# 2025-07-02 17:09:32 [INFO   ] training_mode: traditional
# 2025-07-02 17:10:33 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:10:34 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:10:34 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:10:34 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:10:34 [INFO   ] Extractor: {'type': 'cnn'}
# 2025-07-02 17:10:34 [INFO   ] Fuser: {'type': 'film'}
# 2025-07-02 17:10:34 [INFO   ] training_mode: traditional
# 2025-07-02 17:10:38 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:10:39 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:10:39 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:10:39 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:10:39 [INFO   ] Extractor: {'type': 'identity'}
# 2025-07-02 17:10:39 [INFO   ] Fuser: {'type': 'film'}
# 2025-07-02 17:10:39 [INFO   ] training_mode: traditional
# 2025-07-02 17:10:51 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:10:52 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:10:52 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:10:52 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:10:52 [INFO   ] Extractor: {'type': 'identity'}
# 2025-07-02 17:10:52 [INFO   ] Fuser: {'type': 'bias_scale'}
# 2025-07-02 17:10:52 [INFO   ] training_mode: traditional
# 2025-07-02 17:10:54 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:10:55 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:10:55 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:10:55 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:10:55 [INFO   ] Extractor: {'type': 'cnn'}
# 2025-07-02 17:10:55 [INFO   ] Fuser: {'type': 'bias_scale'}
# 2025-07-02 17:10:55 [INFO   ] training_mode: traditional
# 2025-07-02 17:12:00 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:12:00 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:12:00 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:12:00 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:12:00 [INFO   ] Extractor: {'type': 'identity'}
# 2025-07-02 17:12:00 [INFO   ] Fuser: {'type': 'film'}
# 2025-07-02 17:12:00 [INFO   ] training_mode: traditional
# 2025-07-02 17:12:09 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:12:10 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:12:10 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:12:10 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:12:10 [INFO   ] Extractor: {'type': 'identity'}
# 2025-07-02 17:12:10 [INFO   ] Fuser: {'type': 'bias_scale'}
# 2025-07-02 17:12:10 [INFO   ] training_mode: traditional
# 2025-07-02 17:13:00 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:13:01 [INFO   ] Trend Contribution: 1.00% | Physics Contribution: 1.00%
# 2025-07-02 17:13:02 [INFO   ] ← Chunk complete, 5 models aggregated
# 2025-07-02 17:13:02 [INFO   ]   → dict_keys(['successful_models', 'alpha', 'pred_test', 'res_test', 'alpha_test', 'pred_val', 'q_phys', 'res_val', 'alpha_val'])
# 2025-07-02 17:13:02 [INFO   ]   ← Batch 1 done, total models so far: 5/5
# 2025-07-02 17:13:02 [INFO   ] ← Running contribution analysis on aggregated test results
# 2025-07-02 17:13:02 [INFO   ] [Original-units] Mean point-wise physics contribution: 50.98%
# 2025-07-02 17:13:02 [INFO   ] [Original-units] Global physics contribution: 51.05% (alpha média: 30.22%)
# 2025-07-02 17:13:02 [INFO   ] === Contribution Analysis Summary (unidades originais) ===
#
# • Point-wise mean:       50.98%
# • Global aggregate:      51.05% (alpha média: 30.22%)
# 2025-07-02 17:13:02 [INFO   ] ← process_chunks complete, returning test and validation predictions
# 2025-07-02 17:13:09 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:13:10 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:13:10 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:13:10 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:13:10 [INFO   ] Extractor: {'type': 'cnn'}
# 2025-07-02 17:13:10 [INFO   ] Fuser: {'type': 'film'}
# 2025-07-02 17:13:10 [INFO   ] training_mode: traditional
# 2025-07-02 17:13:15 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:13:15 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:13:15 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:13:15 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:13:15 [INFO   ] Extractor: {'type': 'identity'}
# 2025-07-02 17:13:15 [INFO   ] Fuser: {'type': 'film'}
# 2025-07-02 17:13:15 [INFO   ] training_mode: traditional
# 2025-07-02 17:13:27 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:13:27 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:13:27 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:13:27 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:13:27 [INFO   ] Extractor: {'type': 'identity'}
# 2025-07-02 17:13:27 [INFO   ] Fuser: {'type': 'bias_scale'}
# 2025-07-02 17:13:27 [INFO   ] training_mode: traditional
# 2025-07-02 17:14:24 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:14:24 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:14:24 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:14:24 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:14:24 [INFO   ] Extractor: {'type': 'identity'}
# 2025-07-02 17:14:24 [INFO   ] Fuser: {'type': 'film'}
# 2025-07-02 17:14:25 [INFO   ] training_mode: traditional
# 2025-07-02 17:14:41 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:14:41 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:14:41 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:14:41 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:14:41 [INFO   ] Extractor: {'type': 'identity'}
# 2025-07-02 17:14:41 [INFO   ] Fuser: {'type': 'bias_scale'}
# 2025-07-02 17:14:41 [INFO   ] training_mode: traditional
# 2025-07-02 17:14:55 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:14:55 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:14:55 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:14:55 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:14:55 [INFO   ] Extractor: {'type': 'tcn'}
# 2025-07-02 17:14:55 [INFO   ] Fuser: {'type': 'bias_scale'}
# 2025-07-02 17:14:55 [INFO   ] training_mode: traditional
# 2025-07-02 17:15:00 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:15:00 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:15:00 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:15:00 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:15:00 [INFO   ] Extractor: {'type': 'tcn'}
# 2025-07-02 17:15:00 [INFO   ] Fuser: {'type': 'film'}
# 2025-07-02 17:15:01 [INFO   ] training_mode: traditional
# 2025-07-02 17:15:22 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:15:23 [INFO   ] Trend Contribution: 1.00% | Physics Contribution: 1.00%
# 2025-07-02 17:15:23 [INFO   ] ← Chunk complete, 5 models aggregated
# 2025-07-02 17:15:23 [INFO   ]   → dict_keys(['successful_models', 'alpha', 'pred_test', 'res_test', 'alpha_test', 'pred_val', 'q_phys', 'res_val', 'alpha_val'])
# 2025-07-02 17:15:23 [INFO   ]   ← Batch 1 done, total models so far: 5/5
# 2025-07-02 17:15:23 [INFO   ] ← Running contribution analysis on aggregated test results
# 2025-07-02 17:15:23 [INFO   ] [Original-units] Mean point-wise physics contribution: 53.27%
# 2025-07-02 17:15:23 [INFO   ] [Original-units] Global physics contribution: 53.50% (alpha média: 30.29%)
# 2025-07-02 17:15:23 [INFO   ] === Contribution Analysis Summary (unidades originais) ===
#
# • Point-wise mean:       53.27%
# • Global aggregate:      53.50% (alpha média: 30.29%)
# 2025-07-02 17:15:23 [INFO   ] ← process_chunks complete, returning test and validation predictions
# 2025-07-02 17:15:30 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:15:30 [INFO   ] Trend Contribution: 1.00% | Physics Contribution: 1.00%
# 2025-07-02 17:15:31 [INFO   ] ← Chunk complete, 5 models aggregated
# 2025-07-02 17:15:31 [INFO   ]   → dict_keys(['successful_models', 'alpha', 'pred_test', 'res_test', 'alpha_test', 'pred_val', 'q_phys', 'res_val', 'alpha_val'])
# 2025-07-02 17:15:31 [INFO   ]   ← Batch 1 done, total models so far: 5/5
# 2025-07-02 17:15:31 [INFO   ] ← Running contribution analysis on aggregated test results
# 2025-07-02 17:15:31 [INFO   ] [Original-units] Mean point-wise physics contribution: 47.25%
# 2025-07-02 17:15:31 [INFO   ] [Original-units] Global physics contribution: 47.25% (alpha média: 30.42%)
# 2025-07-02 17:15:31 [INFO   ] === Contribution Analysis Summary (unidades originais) ===
#
# • Point-wise mean:       47.25%
# • Global aggregate:      47.25% (alpha média: 30.42%)
# 2025-07-02 17:15:31 [INFO   ] ← process_chunks complete, returning test and validation predictions
# 2025-07-02 17:15:45 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:15:45 [INFO   ] Trend Contribution: 1.00% | Physics Contribution: 1.00%
# 2025-07-02 17:15:45 [INFO   ] ← Chunk complete, 5 models aggregated
# 2025-07-02 17:15:45 [INFO   ]   → dict_keys(['successful_models', 'alpha', 'pred_test', 'res_test', 'alpha_test', 'pred_val', 'q_phys', 'res_val', 'alpha_val'])
# 2025-07-02 17:15:45 [INFO   ]   ← Batch 1 done, total models so far: 5/5
# 2025-07-02 17:15:45 [INFO   ] ← Running contribution analysis on aggregated test results
# 2025-07-02 17:15:46 [INFO   ] [Original-units] Mean point-wise physics contribution: 45.33%
# 2025-07-02 17:15:46 [INFO   ] [Original-units] Global physics contribution: 44.80% (alpha média: 30.21%)
# 2025-07-02 17:15:46 [INFO   ] === Contribution Analysis Summary (unidades originais) ===
#
# • Point-wise mean:       45.33%
# • Global aggregate:      44.80% (alpha média: 30.21%)
# 2025-07-02 17:15:46 [INFO   ] ← process_chunks complete, returning test and validation predictions
# 2025-07-02 17:25:06 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:25:07 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:25:07 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:25:07 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:25:07 [INFO   ] Extractor: {'type': 'tcn'}
# 2025-07-02 17:25:07 [INFO   ] Fuser: {'type': 'bias_scale'}
# 2025-07-02 17:25:07 [INFO   ] training_mode: traditional
# 2025-07-02 17:25:25 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:25:26 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:25:26 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:25:26 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:25:26 [INFO   ] Extractor: {'type': 'rnn'}
# 2025-07-02 17:25:26 [INFO   ] Fuser: {'type': 'bias_scale'}
# 2025-07-02 17:25:26 [INFO   ] training_mode: traditional
# 2025-07-02 17:25:38 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:25:38 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:25:38 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:25:38 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:25:38 [INFO   ] Extractor: {'type': 'tcn'}
# 2025-07-02 17:25:38 [INFO   ] Fuser: {'type': 'film'}
# 2025-07-02 17:25:39 [INFO   ] training_mode: traditional
# 2025-07-02 17:26:02 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:26:02 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:26:02 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:26:02 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:26:02 [INFO   ] Extractor: {'type': 'rnn'}
# 2025-07-02 17:26:02 [INFO   ] Fuser: {'type': 'film'}
# 2025-07-02 17:26:03 [INFO   ] training_mode: traditional
# 2025-07-02 17:35:32 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:35:33 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:35:33 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:35:33 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:35:33 [INFO   ] Extractor: {'type': 'tcn'}
# 2025-07-02 17:35:33 [INFO   ] Fuser: {'type': 'bias_scale'}
# 2025-07-02 17:35:33 [INFO   ] training_mode: traditional
# 2025-07-02 17:36:33 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:36:33 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:36:33 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:36:33 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:36:33 [INFO   ] Extractor: {'type': 'tcn'}
# 2025-07-02 17:36:33 [INFO   ] Fuser: {'type': 'film'}
# 2025-07-02 17:36:33 [INFO   ] training_mode: traditional
# 2025-07-02 17:46:03 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:46:04 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:46:04 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:46:04 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:46:04 [INFO   ] Extractor: {'type': 'tcn'}
# 2025-07-02 17:46:04 [INFO   ] Fuser: {'type': 'bias_scale'}
# 2025-07-02 17:46:04 [INFO   ] training_mode: traditional
# 2025-07-02 17:47:34 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:47:34 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:47:34 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:47:34 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:47:34 [INFO   ] Extractor: {'type': 'tcn'}
# 2025-07-02 17:47:34 [INFO   ] Fuser: {'type': 'film'}
# 2025-07-02 17:47:34 [INFO   ] training_mode: traditional
# 2025-07-02 17:47:42 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:47:42 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:47:42 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:47:42 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:47:42 [INFO   ] Extractor: {'type': 'rnn'}
# 2025-07-02 17:47:42 [INFO   ] Fuser: {'type': 'bias_scale'}
# 2025-07-02 17:47:43 [INFO   ] training_mode: traditional
# 2025-07-02 17:48:49 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:48:50 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 17:48:50 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 17:48:50 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 17:48:50 [INFO   ] Extractor: {'type': 'rnn'}
# 2025-07-02 17:48:50 [INFO   ] Fuser: {'type': 'film'}
# 2025-07-02 17:48:51 [INFO   ] training_mode: traditional
# 2025-07-02 17:56:10 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:56:10 [INFO   ] Trend Contribution: 1.00% | Physics Contribution: 1.00%
# 2025-07-02 17:56:11 [INFO   ] ← Chunk complete, 5 models aggregated
# 2025-07-02 17:56:11 [INFO   ]   → dict_keys(['successful_models', 'alpha', 'pred_test', 'res_test', 'alpha_test', 'pred_val', 'q_phys', 'res_val', 'alpha_val'])
# 2025-07-02 17:56:11 [INFO   ]   ← Batch 1 done, total models so far: 5/5
# 2025-07-02 17:56:11 [INFO   ] ← Running contribution analysis on aggregated test results
# 2025-07-02 17:56:11 [INFO   ] [Original-units] Mean point-wise physics contribution: 45.18%
# 2025-07-02 17:56:11 [INFO   ] [Original-units] Global physics contribution: 45.17% (alpha média: 30.29%)
# 2025-07-02 17:56:11 [INFO   ] === Contribution Analysis Summary (unidades originais) ===
#
# • Point-wise mean:       45.18%
# • Global aggregate:      45.17% (alpha média: 30.29%)
# 2025-07-02 17:56:11 [INFO   ] ← process_chunks complete, returning test and validation predictions
# 2025-07-02 17:58:05 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 17:58:05 [INFO   ] Trend Contribution: 1.00% | Physics Contribution: 1.00%
# 2025-07-02 17:58:06 [INFO   ] ← Chunk complete, 5 models aggregated
# 2025-07-02 17:58:06 [INFO   ]   → dict_keys(['successful_models', 'alpha', 'pred_test', 'res_test', 'alpha_test', 'pred_val', 'q_phys', 'res_val', 'alpha_val'])
# 2025-07-02 17:58:06 [INFO   ]   ← Batch 1 done, total models so far: 5/5
# 2025-07-02 17:58:06 [INFO   ] ← Running contribution analysis on aggregated test results
# 2025-07-02 17:58:06 [INFO   ] [Original-units] Mean point-wise physics contribution: 46.56%
# 2025-07-02 17:58:06 [INFO   ] [Original-units] Global physics contribution: 46.74% (alpha média: 30.30%)
# 2025-07-02 17:58:06 [INFO   ] === Contribution Analysis Summary (unidades originais) ===
#
# • Point-wise mean:       46.56%
# • Global aggregate:      46.74% (alpha média: 30.30%)
# 2025-07-02 17:58:06 [INFO   ] ← process_chunks complete, returning test and validation predictions
# 2025-07-02 18:04:49 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 18:04:49 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 18:04:49 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 18:04:49 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 18:04:49 [INFO   ] Extractor: {'type': 'rnn'}
# 2025-07-02 18:04:49 [INFO   ] Fuser: {'type': 'bias_scale'}
# 2025-07-02 18:04:49 [INFO   ] training_mode: traditional
# 2025-07-02 18:05:46 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 18:05:46 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 18:05:46 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 18:05:46 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 18:05:46 [INFO   ] Extractor: {'type': 'rnn'}
# 2025-07-02 18:05:46 [INFO   ] Fuser: {'type': 'film'}
# 2025-07-02 18:05:47 [INFO   ] training_mode: traditional
# 2025-07-02 18:17:53 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 18:17:54 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 18:17:54 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 18:17:54 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 18:17:54 [INFO   ] Extractor: {'type': 'rnn'}
# 2025-07-02 18:17:54 [INFO   ] Fuser: {'type': 'bias_scale'}
# 2025-07-02 18:17:54 [INFO   ] training_mode: traditional
# 2025-07-02 18:19:02 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 18:19:02 [INFO   ] Criando modelo para arquitetura: 'Seq2Context'
# 2025-07-02 18:19:02 [INFO   ] Encontrado no registry de modelos legados.
# 2025-07-02 18:19:02 [INFO   ] Strategy: {'strategy_name': 'pressure_ensemble'}
# 2025-07-02 18:19:02 [INFO   ] Extractor: {'type': 'rnn'}
# 2025-07-02 18:19:02 [INFO   ] Fuser: {'type': 'film'}
# 2025-07-02 18:19:03 [INFO   ] training_mode: traditional
# 2025-07-02 18:30:53 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 18:30:54 [INFO   ] Trend Contribution: 1.00% | Physics Contribution: 1.00%
# 2025-07-02 18:30:54 [INFO   ] ← Chunk complete, 5 models aggregated
# 2025-07-02 18:30:54 [INFO   ]   → dict_keys(['successful_models', 'alpha', 'pred_test', 'res_test', 'alpha_test', 'pred_val', 'q_phys', 'res_val', 'alpha_val'])
# 2025-07-02 18:30:54 [INFO   ]   ← Batch 1 done, total models so far: 5/5
# 2025-07-02 18:30:54 [INFO   ] ← Running contribution analysis on aggregated test results
# 2025-07-02 18:30:54 [INFO   ] [Original-units] Mean point-wise physics contribution: 44.56%
# 2025-07-02 18:30:54 [INFO   ] [Original-units] Global physics contribution: 44.56% (alpha média: 30.26%)
# 2025-07-02 18:30:54 [INFO   ] === Contribution Analysis Summary (unidades originais) ===
#
# • Point-wise mean:       44.56%
# • Global aggregate:      44.56% (alpha média: 30.26%)
# 2025-07-02 18:30:54 [INFO   ] ← process_chunks complete, returning test and validation predictions
# 2025-07-02 18:32:05 [INFO   ] No suitable Dense layers found for analysis.
# 2025-07-02 18:32:05 [INFO   ] Trend Contribution: 1.00% | Physics Contribution: 1.00%
# 2025-07-02 18:32:06 [INFO   ] ← Chunk complete, 5 models aggregated
# 2025-07-02 18:32:06 [INFO   ]   → dict_keys(['successful_models', 'alpha', 'pred_test', 'res_test', 'alpha_test', 'pred_val', 'q_phys', 'res_val', 'alpha_val'])
# 2025-07-02 18:32:06 [INFO   ]   ← Batch 1 done, total models so far: 5/5
# 2025-07-02 18:32:06 [INFO   ] ← Running contribution analysis on aggregated test results
# 2025-07-02 18:32:06 [INFO   ] [Original-units] Mean point-wise physics contribution: 49.06%
# 2025-07-02 18:32:06 [INFO   ] [Original-units] Global physics contribution: 49.26% (alpha média: 30.37%)
# 2025-07-02 18:32:06 [INFO   ] === Contribution Analysis Summary (unidades originais) ===
#
# • Point-wise mean:       49.06%
# • Global aggregate:      49.26% (alpha média: 30.37%)
# 2025-07-02 18:32:06 [INFO   ] ← process_chunks complete, returning test and validation predictions
# 2025-07-02 18:32:06 [INFO   ] Pipeline finished.
# 2025-07-02 18:32:06 [INFO   ] Results saved to: /home/gabriel/Documentos/Equinor/experiments/V-O-L-V-E_Seq2Context_ens5_20250702
